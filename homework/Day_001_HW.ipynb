# %% [markdown]
# 作業1

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    """
    mse = MSE = sum((y-yp)**2) / len(y)
    return mse

# %%
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 243.101
# The Mean absolute error is 12.240

# %% [markdown]
# 作業2
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 你選的這組資料為何重要：學習從熟悉的世足賽中，球員表現的參數來做分析，也許可以推廣到MLB或是NBA以及台灣球賽的分析中使用。
# (https://www.kaggle.com/karangadiya/fifa19)
#
# 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)：https://sofifa.com/
#
# 蒐集而來的資料型態為何：包含ID、姓名、年齡、國籍、薪資以及各種表現參數的csv檔案。
#
# 這組資料想解決的問題如何評估：也許以某個人當參考數值、或是全體平均當參考數值，再做個人估計指標的評估。

# %% [markdown]
# 作業3
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# 先找出最高業績表現的不論地區、車種、駕駛等等資料，再找出最差的地區、車種、駕駛資料，比較分析找出其中的落差原因。然後讓業績表現較差的單位，改善並修正以提高整體業績表現。
#
# 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)：
# 讓較差業績表現的單位向較佳業績表現的單位學習並改善。
#
# 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)：
# 由於是自營車隊，利用物聯網的概念，由車隊車輛自動回傳載客資訊。
#
# 蒐集而來的資料型態為何：
# 包含載客時間、地點、運送路線、天氣、人數、車資、距離等等資訊的csv檔案。
#
# 你要回答的問題，其如何評估 (tips：你的假設如何驗證)：
# 先量化個數據，找出極大值、極小值、平均數、中位數等統計資料，可能的話，再以視覺化的方式呈現，以利找出載客單位業績表現佳、業績表現差的原因。
